# %% [markdown]
# # Importing Packages

# %%
import sys
import numpy as np 
import matplotlib

# %% [markdown]
# Creates a basic neuron with 3 inputs.
# ![image.png](attachment:image.png)

# %%
inputs = [1,2,3]
weights = [0.2,0.8,-0.5]
bias = 2

# %%
calculation = inputs[0]*weights[0] + inputs[1]*weights[1] + inputs[2]*weights[2] + bias

# %%
calculation
# Out:
# 2.3
